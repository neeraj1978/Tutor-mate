# %% [markdown]
# # TutorMate Demo
# This notebook demonstrates the end-to-end flow of the TutorMate system.

# %%
import os
import sys
sys.path.append('..')

from run_demo import main

# Set your API key here if not in env
# os.environ['GOOGLE_API_KEY'] = 'YOUR_API_KEY'

main()
